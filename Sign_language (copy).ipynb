# %%
#clone YOLOv5 and 
#!git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies
# %pip install -q roboflow

import torch
import os
from IPython.display import Image, clear_output  # to display images
# Out:
# /home/nikhil/self_Project/yolov5
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
from roboflow import Roboflow
rf = Roboflow(model_format="yolov5", notebook="ultralytics")
# Out:
# upload and label your dataset, and get an API KEY here: https://app.roboflow.com/?model=yolov5&ref=ultralytics

# %%
os.environ["DATASET_DIRECTORY"] = "../sign_datasets"

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="your_keys")
project = rf.workspace().project("sign_language-9tf4k")
dataset = project.version(1).download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to ../sign_datasets/sign_language-1 in yolov5pytorch:: 100%|██████████| 672/672 [00:00<00:00, 1964.15it/s]

# %%
#!python train.py --img 416 --batch 16 --epochs 150 --data {dataset.location}/data.yaml --weights yolov5s.pt --cache

# %%
# !python detect.py --weights //home/nikhil/Downloads/sign_l.pt --img 416 --conf 0.1 --source {dataset.location}/test/images
# Out:
# detect: weights=['//home/nikhil/Downloads/sign_l.pt'], source=/home/nikhil/self_Project/sign_datasets/sign_language-1/test/images, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-159-gdb6ec66 torch 1.10.1+cu102 CPU
#
# Fusing layers...
# Model Summary: 213 layers, 7134187 parameters, 0 gradients, 16.2 GFLOPs
# image 1/14 /home/nikhil/self_Project/sign_datasets/sign_language-1/test/images/1_jpg.rf.536a407b17201e6b678a31d169840a24.jpg: 416x416 1 7, 1 Six, 1 Two, Done. (0.098s)
# image 2/14 /home/nikhil/self_Project/sign_datasets/sign_language-1/test/images/3thank_you_png.rf.c9ee844b5fab1230fa8900c36a560c33.jpg: 416x416 1 thank_you, Done. (0.088s)
# ...

# %%
# !python detect.py --weights //home/nikhil/Downloads/sign_l.pt --img 416 --conf 0.1 --source 2
# Out:
# detect: weights=['//home/nikhil/Downloads/sign_l.pt'], source=sign_lang_output1.mp4, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-159-gdb6ec66 torch 1.10.1+cu102 CPU
#
# Fusing layers...
# Model Summary: 213 layers, 7134187 parameters, 0 gradients, 16.2 GFLOPs
# video 1/1 (1/730) /home/nikhil/self_Project/yolov5/sign_lang_output1.mp4: 416x256 Done. (0.126s)
# video 1/1 (2/730) /home/nikhil/self_Project/yolov5/sign_lang_output1.mp4: 416x256 Done. (0.066s)
# video 1/1 (3/730) /home/nikhil/self_Project/yolov5/sign_lang_output1.mp4: 416x256 Done. (0.065s)
# video 1/1 (4/730) /home/nikhil/self_Project/yolov5/sign_lang_output1.mp4: 416x256 Done. (0.066s)
# ...
